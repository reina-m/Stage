# %%
import pandas as pd

# %%
df = pd.read_csv("samples.csv")

# %% [markdown]
# This markdown cell is ignored by the parser.

# %%
filtered = df[df["quality"] > 30]

# %%
filtered.to_csv("filtered.csv")
